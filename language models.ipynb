# %% [markdown]
# # Language Models
#
# ---

# %% [markdown]
# ### Has this every happened to you?
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Which of these phrases is more likely?
#
# - The *thinker* sat on the mat.
# - The *thinker* sat on the cat.
# - The *thinker* sat on the idea.

# %% [markdown]
# ### A language model describes the *probability* of a particular word sequence
#
# - P("The thinker sat on the mat") = 0.00021
# - P("The thinker sat on the cat") = 0.00312
# - p("The thinker sat on the idea") = 0.00596

# %% [markdown]
# ### Language Models
#
# - Learned directly from *text*
#     - sensitive to *which* text
#     - sensitive to *how much* text
# - Many different ways to learn a model and estimate probability

# %% [markdown]
# ### The simple language model: Unigram language model
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Features of a Language Model
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### We can use a language model to estimate a sequence's probability
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The language probabilities we estimate will depend on where and how we learn the model
#
# ![image.png](attachment:image.png)
#
# - P("I like cats") = ?
# - P("House cats ar ea domestic species of small carnivorous mammal") = ?
# - P("Ur cat looks purrfect") = ?

# %% [markdown]
# ### We can generate text from a language model by *sampling* from its probability distribution
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Why doesn't a unigram language model work well in practice?
#
# ![image.png](attachment:image.png)
